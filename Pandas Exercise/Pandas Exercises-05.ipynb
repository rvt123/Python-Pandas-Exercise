# %% [markdown]
# # Pandas Exercise: Apply function (Student Alcohol Consumption)

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Download the dataset from this [address](http://archive.ics.uci.edu/ml/datasets/STUDENT+ALCOHOL+CONSUMPTION).

# %%
alcohol=pd.read_csv("D:/Analytics Labs(Data Science with Python)/Class 7 File + Panas Study Case/2. Pandas Basic Exercises/Pandas Exercise 5 Files/student-por.csv")

# %%
alcohol.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
df1=alcohol

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
df=df1.loc[:, 'school':'guardian']

# %% [markdown]
# ### Step 5. Create a lambda function that captalize strings.

# %%
lambda x : x.upper()
capitalizer = lambda x: x.upper()

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
df['Mjob'].apply(capitalizer).head()
# Out:
# 0    AT_HOME
# 1    AT_HOME
# 2    AT_HOME
# 3     HEALTH
# 4      OTHER
# Name: Mjob, dtype: object

# %%
df['Fjob'].apply(capitalizer).head()
# Out:
# 0     TEACHER
# 1       OTHER
# 2       OTHER
# 3    SERVICES
# 4       OTHER
# Name: Fjob, dtype: object

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian
# 0  course   mother
# 1  course   father
# 2   other   mother
# 3    home   mother
# 4    home   father

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      reason guardian
# 644  course   mother
# 645  course   mother
# 646  course   mother
# 647  course   mother
# 648  course   mother

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and captalize Mjob and Fjob.

# %%
df['Mjob']=df['Mjob'].apply(capitalizer)

# %%
df['Fjob']=df['Fjob'].apply(capitalizer)

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  AT_HOME   TEACHER
# 1     GP   F   17       U     GT3       T     1     1  AT_HOME     OTHER
# 2     GP   F   15       U     LE3       T     1     1  AT_HOME     OTHER
# 3     GP   F   15       U     GT3       T     4     2   HEALTH  SERVICES
# 4     GP   F   16       U     GT3       T     3     3    OTHER     OTHER
#
#    reason guardian
# 0  course   mother
# 1  course   father
# 2   other   mother
# 3    home   mother
# 4    home   father

# %% [markdown]
# ### Step 9. Create a function called majority that return a boolean value to a new column called legal_drinker

# %%
def majority(x):
    if(x<18):
        return False
    else:
        return True

# %%
df['legal_drinker']=df['age'].apply(majority)

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  AT_HOME   TEACHER
# 1     GP   F   17       U     GT3       T     1     1  AT_HOME     OTHER
# 2     GP   F   15       U     LE3       T     1     1  AT_HOME     OTHER
# 3     GP   F   15       U     GT3       T     4     2   HEALTH  SERVICES
# 4     GP   F   16       U     GT3       T     3     3    OTHER     OTHER
#
#    reason guardian  legal_drinker
# 0  course   mother           True
# 1  course   father          False
# 2   other   mother          False
# 3    home   mother          False
# 4    home   father          False

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.
# ##### I know this makes no sense, don't forget it is just an exercise

# %%
def times10(x):
    if(type(x)==int):
         return x*10

# %%
df.applymap(times10).head()
# Out:
#   school   sex  age address famsize Pstatus  Medu  Fedu  Mjob  Fjob reason  \
# 0   None  None  180    None    None    None    40    40  None  None   None
# 1   None  None  170    None    None    None    10    10  None  None   None
# 2   None  None  150    None    None    None    10    10  None  None   None
# 3   None  None  150    None    None    None    40    20  None  None   None
# 4   None  None  160    None    None    None    30    30  None  None   None
#
#   guardian legal_drinker
# 0     None          None
# 1     None          None
# 2     None          None
# 3     None          None
# 4     None          None
