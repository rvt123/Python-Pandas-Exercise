# %% [markdown]
# # Pokemon

# %% [markdown]
# ### Introduction:
#
# This time you will create the data.
#
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Create a data dictionary

# %%
raw_data = {"name": ['Bulbasaur', 'Charmander','Squirtle','Caterpie','Pickachu'],
            "evolution": ['Ivysaur','Charmeleon','Wartortle','Metapod','Richu'],
            "type": ['grass', 'fire', 'water', 'bug','Electric'],
            "hp": [45, 39, 44, 45,50],
            "pokedex": ['yes', 'no','yes','no','yes']                        
            }

# %% [markdown]
# ### Step 3. Assign it to a variable called

# %%
pokemon = pd.DataFrame(raw_data)
pokemon.head()
# Out:
#     evolution  hp        name pokedex      type
# 0     Ivysaur  45   Bulbasaur     yes     grass
# 1  Charmeleon  39  Charmander      no      fire
# 2   Wartortle  44    Squirtle     yes     water
# 3     Metapod  45    Caterpie      no       bug
# 4       Richu  50    Pickachu     yes  Electric

# %% [markdown]
# ### Step 4. Ops...it seems the DataFrame columns are in alphabetical order. Place  the order of the columns as name, type, hp, evolution, pokedex

# %%
pokemon = pokemon[['name', 'type', 'hp', 'evolution','pokedex']]
pokemon
# Out:
#          name      type  hp   evolution pokedex
# 0   Bulbasaur     grass  45     Ivysaur     yes
# 1  Charmander      fire  39  Charmeleon      no
# 2    Squirtle     water  44   Wartortle     yes
# 3    Caterpie       bug  45     Metapod      no
# 4    Pickachu  Electric  50       Richu     yes

# %% [markdown]
# ### Step 5. Add another column called place, and insert what you have in mind.

# %%
pokemon['place'] = ['park','street','lake','forest','Lab']
pokemon
# Out:
#          name      type  hp   evolution pokedex   place
# 0   Bulbasaur     grass  45     Ivysaur     yes    park
# 1  Charmander      fire  39  Charmeleon      no  street
# 2    Squirtle     water  44   Wartortle     yes    lake
# 3    Caterpie       bug  45     Metapod      no  forest
# 4    Pickachu  Electric  50       Richu     yes     Lab

# %% [markdown]
# ### Step 6. Present the type of each column

# %%
pokemon.dtypes
# Out:
# name         object
# type         object
# hp            int64
# evolution    object
# pokedex      object
# place        object
# dtype: object

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %% [markdown]
# Print the List of pokemon which are present in the Pokedex

# %%
pokemon[pokemon.pokedex=="yes"]
# Out:
#         name      type  hp  evolution pokedex place
# 0  Bulbasaur     grass  45    Ivysaur     yes  park
# 2   Squirtle     water  44  Wartortle     yes  lake
# 4   Pickachu  Electric  50      Richu     yes   Lab

# %% [markdown]
# Sort all the Pokemon with decreasing hp

# %%
pokemon.sort_values(by='hp',ascending=False)
# Out:
#          name      type  hp   evolution pokedex   place
# 4    Pickachu  Electric  50       Richu     yes     Lab
# 0   Bulbasaur     grass  45     Ivysaur     yes    park
# 3    Caterpie       bug  45     Metapod      no  forest
# 2    Squirtle     water  44   Wartortle     yes    lake
# 1  Charmander      fire  39  Charmeleon      no  street
