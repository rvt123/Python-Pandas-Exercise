# %% [markdown]
# # Pandas Exercise: Time Series (Getting Financial Data - Google Finance)

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import quandl

# %% [markdown]
# * Google Finance API is not working so I have used Quandl API for data

# %% [markdown]
# ### Step 2. Create your time range (start and end variables). The start date should be 01/01/2015 and the end should today (whatever your today is)

# %%
start='01-01-2015'
end='17-08-2018'

# %% [markdown]
# ### Step 3. Select the Apple, Tesla, Twitter, IBM, LinkedIn stocks symbols and assign them to a variable called stocks

# %%
stock=['EOD/AAPL','EOD/IBM','SSE/TL0']

# %% [markdown]
# ### Step 4. Read the data from google, assign to df and print it

# %%
quandl.ApiConfig.api_key='83dh9uBg6s2UyUht1N6z'
df=quandl.get(stock,start_date=start,end_date=end)

# %%
df.tail()
# Out:
#             EOD/AAPL - Open  EOD/AAPL - High  EOD/AAPL - Low  \
# Date
# 2018-08-13          207.700         210.9520          207.70
# 2018-08-14          210.155         210.5600          208.26
# 2018-08-15          209.220         210.7400          208.33
# 2018-08-16          211.750         213.8121          211.47
# 2018-08-17          213.440         217.9500          213.16
#
#             EOD/AAPL - Close  EOD/AAPL - Volume  EOD/AAPL - Dividend  \
# Date
# 2018-08-13            208.87         25890880.0                  0.0
# 2018-08-14            209.75         20748010.0                  0.0
# 2018-08-15            210.24         28807564.0                  0.0
# 2018-08-16            213.32         28500367.0                  0.0
# 2018-08-17            217.58         35426997.0                  0.0
#
#             EOD/AAPL - Split  EOD/AAPL - Adj_Open  EOD/AAPL - Adj_High  \
# Date
# 2018-08-13               1.0              207.700             210.9520
# ...

# %% [markdown]
# ### Step 5.  What is the type of structure of df ?

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Step 6. Print all the Items axis values
# #### To learn more about the Panel structure go to [documentation](http://pandas.pydata.org/pandas-docs/stable/dsintro.html#panel)

# %%
df.items
# Out:
# <bound method DataFrame.iteritems of             EOD/AAPL - Open  EOD/AAPL - High  EOD/AAPL - Low  \
# Date
# 2015-01-02         111.3900         111.4400        107.3500
# 2015-01-05         108.2900         108.6500        105.4100
# 2015-01-06         106.5400         107.4300        104.6300
# 2015-01-07         107.2000         108.2000        106.6950
# 2015-01-08         109.2300         112.1500        108.7000
# 2015-01-09         112.6700         113.2500        110.2100
# 2015-01-12         112.6000         112.6300        108.8000
# 2015-01-13         111.4300         112.8000        108.9100
# 2015-01-14         109.0400         110.4900        108.5000
# 2015-01-15         110.0000         110.0600        106.6600
# 2015-01-16         107.0300         107.5800        105.2000
# 2015-01-19              NaN              NaN             NaN
# 2015-01-20         107.8400         108.9667        106.5000
# 2015-01-21         108.9500         111.0600        108.2700
# ...

# %% [markdown]
# ### Step 7. Good, now we know  the data available. Create a dataFrame called vol, with the Volume values.

# %%
vol=df[['EOD/AAPL - Volume','EOD/IBM - Adj_Volume','SSE/TL0 - Volume']]
vol.tail()
# Out:
#             EOD/AAPL - Volume  EOD/IBM - Adj_Volume  SSE/TL0 - Volume
# Date
# 2018-08-13         25890880.0             2858561.0            1767.0
# 2018-08-14         20748010.0             2860006.0             284.0
# 2018-08-15         28807564.0             4241068.0             522.0
# 2018-08-16         28500367.0             5250878.0             203.0
# 2018-08-17         35426997.0             2678645.0             349.0

# %%
vol.rename(columns={'EOD/AAPL - Volume':'AAPL','EOD/IBM - Adj_Volume':'IBM','SSE/TL0 - Volume':'TL0'},inplace=True)
# Out:
# C:\Users\raghu\Anaconda3\lib\site-packages\pandas\core\frame.py:3778: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %% [markdown]
# ### Step 8. Aggregate the data of Volume to weekly
# #### Hint: Be careful to not sum data from the same week of 2015 and other years.

# %%
vol.resample('W').sum().head()
# Out:
#                    AAPL         IBM  TL0
# Date
# 2015-01-04   53204626.0   5525341.0  0.0
# 2015-01-11  282868187.0  24440360.0  0.0
# 2015-01-18  304226647.0  23272056.0  0.0
# 2015-01-25  198737041.0  31230797.0  0.0
# 2015-02-01  465842684.0  32927307.0  0.0

# %% [markdown]
# ### Step 9. Find all the volume traded in the year of 2015

# %%
z=vol.groupby(vol.index.year).sum()
z[z.index==2015]
# Out:
#               AAPL           IBM  TL0
# Date
# 2015  1.306432e+10  1.105546e+09  0.0

# %% [markdown]
# ### BONUS: Create your own question and answer it.
